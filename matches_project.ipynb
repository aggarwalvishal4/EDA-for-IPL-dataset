# %% [markdown]
# # Matches Analysis

# %% [markdown]
# ## 1. Problem Statement

# %% [markdown]
# The notebooks explores the basic use of __Pandas__ and will cover the basic commands of __Exploratory Data Analysis(EDA)__ which includes __cleaning__, __munging__, __combining__, __reshaping__, __slicing__, __dicing__, and __transforming data__ for analysis purpose.
#
# * __Exploratory Data Analysis__ <br/>
# Understand the data by EDA and derive simple models with Pandas as baseline.
# EDA ia a critical and first step in analyzing the data and we do this for below reasons :
#     - Finding patterns in Data
#     - Determining relationships in Data
#     - Checking of assumptions
#     - Preliminary selection of appropriate models
#     - Detection of mistakes

# %% [markdown]
# ## 2. Loading Data and Description
# ![title](ipl.png)

# %% [markdown]
# - The dataset consists of the information about matches from the famous Indian Premier League. Various variables present in the dataset includes data of season, city, teams etc.
# - The dataset comprises of __696 observations of 18 columns__. Below is a table showing names of all the columns and their description.

# %% [markdown]
# | Column Name     | Description                                               |
# | -------------   |:-------------                                            :|
# | id              | Identity Column                                           |
# | season          | Year in which Match                                       |
# | city            | City where match has been played                          |
# | date            | Date on which Match has been played                       |
# | team1           | First Team                                                |
# | team2           | Second Team                                               |
# | toss_winner     | Team who won the Toss                                     |
# | toss_decision   | What does team has decide whether to bat or field first   |
# | result          | normal, no result or tie                                  |
# | dl_applied      | 0 for False and 1 for True                                |
# | winner          | Team won                                                  |
# | win_by_runs     | Margin of runs in victory                                 |
# | win_by_wickets  | By How many wickets team has won                          |
# | player_of_match | Player who has performed best in that Match               |
# | venue           | Name of stadium                                           |
# | umpire1         | Name of Umpire1                                           |
# | umpire2         | Name of Umpire2                                           |
# | umpire3         | Name of Umpire3                                           |

# %% [markdown]
# #### Some Background Information
# The __Indian Premier League__ (IPL), officially Vivo Indian Premier League for sponsorship reasons, is a professional __Twenty20__ cricket league in India contested during __April and May__ of every year by teams representing __Indian Citites and some States__. The League was founded by the __Board of Control for Cricket in India(BCCI)__ in 2008, and is regarded as the brainchild of __Lalit Modi__, the fouder and former commissioner of the league.<br/>
# The IPL is the most-attended cricket league in the world and in 2014 __ranked sixth__ by average attendance among all sports leagues. In 2010, the IPL became the first sporting event in the world to be broadcast live on YouTube. The brand value of IPL in 2018 was __US$6.3 billion__, according to __Duff & Phelps__. According to BCCI, the 2015 IPL season contributed __₹11.5 billion (USD182 million)__ to the GDP of the Indian economy.

# %% [markdown]
# ### Loading of Libraries

# %%
#Import of necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import pandas_profiling

# %% [markdown]
# #### Importing the Dataset

# %%
#Import matches.csv as DataFrame

matches = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/matches.csv')
matches
# Out:
#        id  season       city        date                        team1  \
# 0       1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1       2    2017       Pune  2017-04-06               Mumbai Indians
# 2       3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3       4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4       5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5       6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6       7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7       8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8       9    2017       Pune  2017-04-11             Delhi Daredevils
# 9      10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 10     11    2017    Kolkata  2017-04-13              Kings XI Punjab
# 11     12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %% [markdown]
# ## 3. Data Profiling

# %% [markdown]
# - In the upcoming sections we will first __understand our dataset__ using various pandas functionalities.
# - Then with the help of __pandas profiling__ we will find which columns of our dataset need preprocessing.
# - In __preprocessing__ we will deal with erronous and missing values of columns.
# - Again we will do __pandas profiling__ to see how preprocessing have transformed our dataset.

# %% [markdown]
# ### 3.1 Understanding the Dataset

# %%
matches.shape                                        #This will print the number of rows and columns in Data.
# Out:
# (696, 18)

# %% [markdown]
# Matches data has __696 rows__ and __18 columns__.

# %%
matches.columns                                      #This will give me the names of the columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
matches.head()                                       #This will print the starting 5 records of data
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.tail()                                      #This will print last 5 record of data
# Out:
#        id  season     city      date                  team1  \
# 691  7949    2018     Pune  20/05/18        Kings XI Punjab
# 692  7950    2018   Mumbai  22/05/18    Sunrisers Hyderabad
# 693  7951    2018  Kolkata  23/05/18  Kolkata Knight Riders
# 694  7952    2018  Kolkata  25/05/18    Sunrisers Hyderabad
# 695  7953    2018   Mumbai  27/05/18    Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# 691    Chennai Super Kings    Chennai Super Kings         field  normal
# 692    Chennai Super Kings    Chennai Super Kings         field  normal
# 693       Rajasthan Royals       Rajasthan Royals         field  normal
# 694  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 695    Chennai Super Kings    Chennai Super Kings         field  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# 691           0    Chennai Super Kings            0               5
# ...

# %%
matches.info()                                          # This will give Index, Datatype and Memory information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 18 columns):
# id                 696 non-null int64
# season             696 non-null int64
# city               689 non-null object
# date               696 non-null object
# team1              696 non-null object
# team2              696 non-null object
# toss_winner        696 non-null object
# toss_decision      696 non-null object
# result             696 non-null object
# dl_applied         696 non-null int64
# winner             693 non-null object
# win_by_runs        696 non-null int64
# win_by_wickets     696 non-null int64
# player_of_match    693 non-null object
# venue              696 non-null object
# umpire1            695 non-null object
# umpire2            695 non-null object
# umpire3            60 non-null object
# dtypes: int64(5), object(13)
# memory usage: 98.0+ KB

# %%
matches.describe()                      #This will give us the mean, count etc information related to numerical columns.
# Out:
#                 id       season  dl_applied  win_by_runs  win_by_wickets
# count   696.000000   696.000000  696.000000   696.000000      696.000000
# mean    974.103448  2012.965517    0.027299    13.472701        3.349138
# std    2143.239623     3.069266    0.163070    23.607994        3.411398
# min       1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%     174.750000  2010.000000    0.000000     0.000000        0.000000
# 50%     348.500000  2013.000000    0.000000     0.000000        3.000000
# 75%     522.250000  2016.000000    0.000000    19.000000        6.000000
# max    7953.000000  2018.000000    1.000000   146.000000       10.000000

# %%
matches.isnull().sum()                                    #This will give us the coulumn wise null counts.
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %% [markdown]
# From the above output we can see that __Umpire3__ gives the maximum null values and we will deal with it later.

# %% [markdown]
# ### 3.2 Pre Profiling

# %% [markdown]
# - By pandas profiling, an __interactive HTML report__ gets generated which contins all the information about the columns of the dataset, like the __counts and type__ of each _column_. Detailed information about each column, __coorelation between different columns__ and a sample of dataset.<br/>
# - It gives us __visual interpretation__ of each column in the data.
# - _Spread of the data_ can be better understood by the distribution plot.
# - _Grannular level_ analysis of each column.

# %%
profile = pandas_profiling.ProfileReport(matches)
profile.to_file(outputfile="matches_before_preprocessing.html")

# %% [markdown]
# ### 3.3 Preprocessing

# %% [markdown]
# - Dealing with missing values<br/>
#     - Dropping missing entries of __umpire3.__
#     - Replacing missing values of __winner__ with __N/A__ values as these matches were having __no result__.
#     - Changing __city__ to _Abu Dhabi_ as they are from _Dubai_ Venue.
#     - Replacing values of __winner__ with _N/A_ values as those matches were _tie_.
#     - Added a new column __loser__ to the dataset.

# %%
matches[matches['winner'].isnull()] #analyzing data where winner is null
# Out:
#       id  season       city        date                        team1  \
# 300  301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    NaN            0               0
# 545  no result           0    NaN            0               0
# 570  no result           0    NaN            0               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# ...

# %%
matches[matches['city'].isnull()]   #analyzing data where city is null
# Out:
#       id  season city        date                        team1  \
# 461  462    2014  NaN  2014-04-19               Mumbai Indians
# 462  463    2014  NaN  2014-04-19        Kolkata Knight Riders
# 466  467    2014  NaN  2014-04-23          Chennai Super Kings
# 468  469    2014  NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014  NaN  2014-04-25               Mumbai Indians
# 474  475    2014  NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014  NaN  2014-04-30          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 461  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 462             Delhi Daredevils        Kolkata Knight Riders           bat
# 466             Rajasthan Royals             Rajasthan Royals         field
# 468             Delhi Daredevils          Sunrisers Hyderabad           bat
# 469          Chennai Super Kings               Mumbai Indians           bat
# ...

# %%
matches[matches['umpire1'].isnull()]   #analyzing data where umpire1 is null
# Out:
#    id  season       city        date                        team1  \
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#               team2                  toss_winner toss_decision  result  \
# 4  Delhi Daredevils  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 4           0  Royal Challengers Bangalore           15               0
#
#   player_of_match                  venue umpire1 umpire2 umpire3
# 4       KM Jadhav  M Chinnaswamy Stadium     NaN     NaN     NaN

# %%
matches[matches['player_of_match'].isnull()] #analyzing data where man of the match is null
# Out:
#       id  season       city        date                        team1  \
# 300  301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    NaN            0               0
# 545  no result           0    NaN            0               0
# 570  no result           0    NaN            0               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# ...

# %%
matches[matches['result'] == "tie"]  #analyzing data where result is tie
# Out:
#       id  season       city        date                        team1  \
# 33    34    2017     Rajkot  2017-04-29                Gujarat Lions
# 125  126    2009  Cape Town  2009-04-23             Rajasthan Royals
# 189  190    2010    Chennai  2010-03-21              Kings XI Punjab
# 387  388    2013  Hyderabad  2013-04-07  Royal Challengers Bangalore
# 400  401    2013  Bangalore  2013-04-16             Delhi Daredevils
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 535  536    2015  Ahmedabad  2015-04-21             Rajasthan Royals
#
#                            team2                  toss_winner toss_decision  \
# 33                Mumbai Indians                Gujarat Lions           bat
# 125        Kolkata Knight Riders        Kolkata Knight Riders         field
# 189          Chennai Super Kings          Chennai Super Kings         field
# 387          Sunrisers Hyderabad  Royal Challengers Bangalore           bat
# ...

# %%
#getting index of cities where it is null
matches_processed = matches
#setting city as Abu Dhabi where city is null because venue is from Abu Dhabi
matches_processed[['city']] = matches_processed[['city']].fillna(value="Abu Dhabi")

# %%
matches_processed[matches_processed["city"]=="Abu Dhabi"]
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 461  462    2014  Abu Dhabi  2014-04-19               Mumbai Indians
# 462  463    2014  Abu Dhabi  2014-04-19        Kolkata Knight Riders
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 466  467    2014  Abu Dhabi  2014-04-23          Chennai Super Kings
# 468  469    2014  Abu Dhabi  2014-04-25          Sunrisers Hyderabad
# 469  470    2014  Abu Dhabi  2014-04-25               Mumbai Indians
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 474  475    2014  Abu Dhabi  2014-04-28  Royal Challengers Bangalore
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# ...

# %%
np.unique(matches_processed['team1']) #checking team names
# replacing Rising Pune Supergiants with Rising Pune Supergiant as these are same teams.
matches_processed = matches_processed.where(matches_processed != 'Rising Pune Supergiants', 'Rising Pune Supergiant')
np.unique(matches_processed['team1']) #validating replacement
# Out:
# array(['Chennai Super Kings', 'Deccan Chargers', 'Delhi Daredevils',
#        'Gujarat Lions', 'Kings XI Punjab', 'Kochi Tuskers Kerala',
#        'Kolkata Knight Riders', 'Mumbai Indians', 'Pune Warriors',
#        'Rajasthan Royals', 'Rising Pune Supergiant',
#        'Royal Challengers Bangalore', 'Sunrisers Hyderabad'], dtype=object)

# %%
matches_processed = matches_processed.drop('umpire3', axis=1) #dropping of umpire3 column
matches_processed
# Out:
#        id  season       city        date                        team1  \
# 0       1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1       2    2017       Pune  2017-04-06               Mumbai Indians
# 2       3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3       4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4       5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5       6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6       7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7       8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8       9    2017       Pune  2017-04-11             Delhi Daredevils
# 9      10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 10     11    2017    Kolkata  2017-04-13              Kings XI Punjab
# 11     12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
matches_processed.loc[matches_processed['result'] == 'tie','winner'] = np.nan #replacing winner with NaN where match is tie
matches_processed[matches_processed['result'] == 'tie']
# Out:
#       id  season       city        date                        team1  \
# 33    34    2017     Rajkot  2017-04-29                Gujarat Lions
# 125  126    2009  Cape Town  2009-04-23             Rajasthan Royals
# 189  190    2010    Chennai  2010-03-21              Kings XI Punjab
# 387  388    2013  Hyderabad  2013-04-07  Royal Challengers Bangalore
# 400  401    2013  Bangalore  2013-04-16             Delhi Daredevils
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 535  536    2015  Ahmedabad  2015-04-21             Rajasthan Royals
#
#                            team2                  toss_winner toss_decision  \
# 33                Mumbai Indians                Gujarat Lions           bat
# 125        Kolkata Knight Riders        Kolkata Knight Riders         field
# 189          Chennai Super Kings          Chennai Super Kings         field
# 387          Sunrisers Hyderabad  Royal Challengers Bangalore           bat
# ...

# %%
matches_processed=matches_processed.replace(np.NaN,'N/A') #replacing NaN with N/A in player of match column

# %%
matches_processed[matches_processed['player_of_match']=='N/A'] #validating NaN replacement
# Out:
#       id  season       city        date                        team1  \
# 300  301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    N/A            0               0
# 545  no result           0    N/A            0               0
# 570  no result           0    N/A            0               0
#
#     player_of_match                  venue          umpire1       umpire2
# ...

# %%
#Adding of Loser Column
loser = []
for index, row in matches_processed.iterrows():
    if(row['team1'] == row['winner']):
        loser.append(row['team2'])
    elif(row['team2'] == row['winner']):
        loser.append(row['team1'])
    else:
        loser.append('N/A')
matches_processed['loser'] = pd.Series(loser, index = matches_processed.index)
matches_processed
# Out:
#        id  season       city        date                        team1  \
# 0       1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1       2    2017       Pune  2017-04-06               Mumbai Indians
# 2       3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3       4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4       5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5       6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6       7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7       8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8       9    2017       Pune  2017-04-11             Delhi Daredevils
# 9      10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 10     11    2017    Kolkata  2017-04-13              Kings XI Punjab
# 11     12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %% [markdown]
# ## 3.4 Post Pandas Profiling

# %%
matches_processed.shape
# Out:
# (696, 18)

# %%
matches_processed.describe()
# Out:
#                 id       season  dl_applied  win_by_runs  win_by_wickets
# count   696.000000   696.000000  696.000000   696.000000      696.000000
# mean    974.103448  2012.965517    0.027299    13.472701        3.349138
# std    2143.239623     3.069266    0.163070    23.607994        3.411398
# min       1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%     174.750000  2010.000000    0.000000     0.000000        0.000000
# 50%     348.500000  2013.000000    0.000000     0.000000        3.000000
# 75%     522.250000  2016.000000    0.000000    19.000000        6.000000
# max    7953.000000  2018.000000    1.000000   146.000000       10.000000

# %%
matches_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 18 columns):
# id                 696 non-null int64
# season             696 non-null int64
# city               696 non-null object
# date               696 non-null object
# team1              696 non-null object
# team2              696 non-null object
# toss_winner        696 non-null object
# toss_decision      696 non-null object
# result             696 non-null object
# dl_applied         696 non-null int64
# winner             696 non-null object
# win_by_runs        696 non-null int64
# win_by_wickets     696 non-null int64
# player_of_match    696 non-null object
# venue              696 non-null object
# umpire1            696 non-null object
# umpire2            696 non-null object
# loser              696 non-null object
# dtypes: int64(5), object(13)
# memory usage: 98.0+ KB

# %%
profile = pandas_profiling.ProfileReport(matches_processed)
profile.to_file(outputfile="matches_after_preprocessing.html")

# %% [markdown]
# Now we have preprocessed the data, now the dataset doesnot contain missing values, we have also introduced new feature named __loser__. So, the pandas profiling report which we have generated after preprocessing will give us more beneficial insights. You can compare the two reports, i.e __matches_after_preprocessing.html__ and __matches_before_preprocessing.html__.<br/>
# In matches_after_preprocessing.html report, observations:
# - In the Dataset info, Total __Missing(%)__ = __0.0%__
# - Number of __variables__ = __18__
# - Observe the newly created variable loser, Click on Toggle details to get more detailed information about it.

# %% [markdown]
# ### 4. Questions

# %% [markdown]
# ### 4.1 Of all the matches, what is result trend on yearly basis?

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot('season',data=matches_processed, hue='result').set_title('Year wise Match Result Trend')
# Out:
# Text(0.5, 1.0, 'Year wise Match Result Trend')

# %% [markdown]
# - You can see maximum matches has been played in __2013__.
# - Number of matches which have been _tie_ and _no result_ are very low.

# %% [markdown]
# ### 4.2 Of all the matches, in which cities tie and no results are there?

# %%
tNData = matches_processed[(matches_processed['result'] == 'no result') | (matches_processed['result'] == 'tie')]
sns.countplot('city',data=tNData, hue='result').set_title("Tie and No Result Trend city wise")
# Out:
# Text(0.5, 1.0, 'Tie and No Result Trend city wise')

# %% [markdown]
# __Bangalore__ has maximum number of __no results__

# %% [markdown]
# ### 4.3 What is overall trend of Match Played, Victory and Loss of Teams

# %%
wins = matches_processed[matches_processed['winner'] != 'N/A'].groupby('winner')['winner'].count()
wins.plot.bar().set_title("Team Victory")
# Out:
# Text(0.5, 1.0, 'Team Victory')

# %% [markdown]
# We can clearly see below outcomes in total match played by teams-
#  - __Mumbai Indians__ has secured maximum victory.
#  - __Kochi Tuskers Kerela__ has minimum victory.

# %%
loss = matches_processed[matches_processed['loser'] != 'N/A'].groupby('loser')['loser'].count()
loss.plot.bar().set_title("Tem wise Loss")
# Out:
# Text(0.5, 1.0, 'Tem wise Loss')

# %% [markdown]
# In total match played by individual teams below is loss analysis-
# - __Delhi Daredevils__ has maximum number of losses.
# - __Kochi Tuskers Kerela__ has minimum number of losses.

# %%
Teams = np.unique(matches_processed['team1'])
TotalMatch = {}
for i in range(0, len(Teams)):
    TotalMatch[Teams[i]] = 0
for index, row in matches_processed.iterrows():
    TotalMatch[row['team1']] = TotalMatch[row['team1']]+1
    TotalMatch[row['team2']] = TotalMatch[row['team2']]+1
TotalMatch
TotalMatchdf = pd.DataFrame.from_dict(TotalMatch, orient = 'index', columns = ['Matches'])
TotalMatchdf.plot.bar().set_title("Number of Match Played - Team Wise")
# Out:
# Text(0.5, 1.0, 'Number of Match Played - Team Wise')

# %% [markdown]
# - __Mumbai Indians__ has played maximum number of matches.
# - __Kochi Tuskers Kerela__ has played minimum number of matches.

# %% [markdown]
# - Overall __Mumbai Indians__ has best performance.
# - Overall __Pune Warriors__ has lowest performance.

# %% [markdown]
# ### 4.4 What is the trend of wins by run and wickets of different teams?

# %%
successful_defend = matches_processed[matches_processed['win_by_runs']>0].groupby('winner')['id'].count()
successful_chase = matches_processed[matches_processed['win_by_wickets']>0].groupby('winner')['id'].count()
successful_defend_df = pd.DataFrame({'Teams':successful_defend.index, 'Matches':successful_defend.values})
successful_defend_df['param'] = 'victory by runs'
successful_chase_df = pd.DataFrame({'Teams':successful_chase.index, 'Matches':successful_chase.values})
successful_chase_df['param'] = 'victory by wickets'
frames = [successful_chase_df, successful_defend_df]
result = pd.concat(frames)

# %matplotlib inline
g = sns.catplot(x='Teams', y='Matches', hue='param', data=result, kind='bar', aspect=2.5)
g.set_xticklabels(rotation=90)
g.fig.suptitle("Wins trend of teams by run and wicket")
# Out:
# Text(0.5, 0.98, 'Wins trend of teams by run and wicket')

# %% [markdown]
# - Overall Maximum victories __Mumbai Indians__ have.
# - Maximum victoreis by runs also __Mumbai Indians__ have.
# - Maximum victories by wicktes __Kolkata Knight Riders__ have.

# %% [markdown]
# ### 4.5 Which Team has the best victory by runs?

# %%
sorted_wins_by_run = matches_processed.sort_values(by=['win_by_runs'], ascending=False)
sorted_wins_by_run_plot = sorted_wins_by_run[sorted_wins_by_run['winner'] != 'N/A'][['winner','win_by_runs']]\
                            .groupby('winner').max()
sorted_wins_by_run_plot.rename(columns={'win_by_runs':'vicotory by runs'}, inplace=True)
sorted_wins_by_run_plot.reset_index(inplace=True)
#sns.barplot(x='winner', y='win_by_runs', data=sorted_wins_by_run_plot, width=.5)

# %matplotlib inline
g = sns.catplot(x='winner', y='vicotory by runs', data=sorted_wins_by_run_plot, kind='bar', aspect=2.5)
g.set_xticklabels(rotation =90)
g.fig.suptitle("Best Victory by Runs")
# Out:
# Text(0.5, 0.98, 'Best Victory by Runs')

# %% [markdown]
# - __Mumbai Indians__ has the maximum run difference victory.
# - With more than __125 runs__ _Mumbai Indians, Royal Challengers Bangalore, Kolkata Knight Riders_ emerged victorious.

# %% [markdown]
# ### 4.6 What is the range of margin of runs in which teams has finished the match?

# %%
victory_by_run_trend = sorted_wins_by_run[(sorted_wins_by_run['winner'] != 'N/A')&\
                                          (sorted_wins_by_run['win_by_runs']!=0)][['winner','win_by_runs']]
victory_by_run_trend.rename(columns={'win_by_runs':'vicotory by runs'}, inplace=True)

# %matplotlib inline
g = sns.catplot(x='winner', y='vicotory by runs', data=victory_by_run_trend, kind='swarm', aspect=2.5)
g.set_xticklabels(rotation =90)
g.fig.suptitle("Run victory trend")
# Out:
# Text(0.5, 0.98, 'Run victory trend')

# %% [markdown]
# - Maximum teams has won matches by the margin of runs in range of __0 to 20__.
# - There are 7 outliers i.e. 7 matches which has been finished by more than a difference of _100 runs_.
# - Maximum outliers or biggest victories which is more than _100 runs_ has been made by __Royal Challengers Bangalore__.

# %% [markdown]
# ### 4.7 Whcih team has won the match with maximum wickets?

# %%
sorted_wins_by_wickets = matches_processed.sort_values(by=['win_by_wickets'], ascending=False)
sorted_wins_by_wickets_plot = sorted_wins_by_wickets[sorted_wins_by_wickets['winner'] != 'N/A'][['winner','win_by_wickets']]\
                            .groupby('winner').max()
sorted_wins_by_wickets_plot.rename(columns={'win_by_wickets':'vicotory by wickets'}, inplace=True)
sorted_wins_by_wickets_plot.reset_index(inplace=True)
#sns.barplot(x='winner', y='win_by_runs', data=sorted_wins_by_run_plot, width=.5)

# %matplotlib inline
g = sns.catplot(x='winner', y='vicotory by wickets', data=sorted_wins_by_wickets_plot,kind='bar', aspect=2.5)
g.set_xticklabels(rotation =90)
g.fig.suptitle("Victory by Maximum wickets")
# Out:
# Text(0.5, 0.98, 'Victory by Maximum wickets')

# %% [markdown]
# - Almost all teams has managed to win one match with _10 wickets_.
# - All teams did manage to win at least _1 match_ with the margin of _7 wickets_.

# %% [markdown]
# ### 4.8 What is the range of winning matches by wickets?

# %%
victory_by_wickets_trend = sorted_wins_by_wickets[(sorted_wins_by_wickets['winner'] != 'N/A')\
                                                  &(sorted_wins_by_wickets['win_by_wickets']!=0)]\
                                                    [['winner','win_by_wickets']]
victory_by_wickets_trend.rename(columns={'win_by_wickets':'vicotory by wickets'}, inplace=True)

# %matplotlib inline
g = sns.catplot(x='winner', y='vicotory by wickets', data=victory_by_wickets_trend, kind='swarm', aspect=2.5)
g.set_xticklabels(rotation =90)
g.fig.suptitle("Match winning trend by wickets")
# Out:
# Text(0.5, 0.98, 'Match winning trend by wickets')

# %% [markdown]
# - Most of the matches has been won with in range of __6 to 8 wickets__.
# - _Kochi Tusker Kerela_ won only 4 matches by wicket but all of them were in the range of _7 to 8 wickets_.

# %% [markdown]
# ### 4.9 Which Team lost with the maximum margin of runs?

# %%
sorted_loss_by_run = matches_processed.sort_values(by=['win_by_runs'], ascending=False)
sorted_loss_by_run_plot = sorted_loss_by_run[sorted_loss_by_run['loser'] != 'N/A'][['loser','win_by_runs']]\
                            .groupby('loser').max()
sorted_loss_by_run_plot.rename(columns={'win_by_runs':'loss by runs'}, inplace=True)
sorted_loss_by_run_plot.reset_index(inplace=True)
#sns.barplot(x='winner', y='win_by_runs', data=sorted_wins_by_run_plot, width=.5)

# %matplotlib inline
g = sns.catplot(x='loser', y='loss by runs', data=sorted_loss_by_run_plot, kind='bar', aspect=2.5)
g.set_xticklabels(rotation =90)
g.fig.suptitle("Maximum margin loss")
# Out:
# Text(0.5, 0.98, 'Maximum margin loss')

# %% [markdown]
# - __Delhi Daredevils__ lost its match with margin of more than __140 runs__.
# - Teams which lost with margin of more than _120 runs_ are _Delhi Daredevils_, _Gujrat Lions_, _Kings XI Punjab_, _Royal Challengers Bangalore_ and _Pune Warriors_.
# - __Kochi Tuskers Kerela__ lost with _minimum_ margin.

# %% [markdown]
# ### 4.10 What is the range where most of teams loss their matches?

# %%
loss_by_run_trend = sorted_loss_by_run[(sorted_loss_by_run['loser'] != 'N/A')\
                                       &(sorted_loss_by_run['win_by_runs']!=0)][['loser','win_by_runs']]
loss_by_run_trend.rename(columns={'win_by_runs':'loss by runs'}, inplace=True)

# %matplotlib inline
g = sns.catplot(x='loser', y='loss by runs', data=loss_by_run_trend, kind='swarm', aspect=2.5)
g.set_xticklabels(rotation =90)
g.fig.suptitle("Matches loss trend")
# Out:
# Text(0.5, 0.98, 'Matches loss trend')

# %% [markdown]
# - Range in which most of teams lost is __0 to 20__ runs.
# - __Rising Pune Supergiant__ lost all of its matches with the lesser margin than _20_ runs.
# - __Gujarat Lions__ lost all of its matches with more than margin then average range margins.

# %% [markdown]
# ### 4.11 Which team lost with maximum wickets?

# %%
sorted_loss_by_wickets = matches_processed.sort_values(by=['win_by_wickets'], ascending=False)
sorted_loss_by_wickets_plot = sorted_wins_by_wickets[sorted_wins_by_wickets['loser'] != 'N/A'][['loser','win_by_wickets']]\
                            .groupby('loser').max()
sorted_loss_by_wickets_plot.rename(columns={'win_by_wickets':'loss by wickets'}, inplace=True)
sorted_loss_by_wickets_plot.reset_index(inplace=True)
#sns.barplot(x='winner', y='win_by_runs', data=sorted_wins_by_run_plot, width=.5)

# %matplotlib inline
g = sns.catplot(x='loser', y='loss by wickets', data=sorted_loss_by_wickets_plot,kind='bar', aspect=2.5)
g.set_xticklabels(rotation =90)
g.fig.suptitle("Lost by maximum wickets")
# Out:
# Text(0.5, 0.98, 'Lost by maximum wickets')

# %% [markdown]
# - __Delhi Daredevils, Gujarat Lions, Kings XI Punjab, Rajasthan Royals__ and __Mumbai Indians__ lost matches with __10 wickets__.
# - Minimum maximum lost by wickets is __8 wickets__ by __Pune Warriors__ and __Rising Pune Supergiant__.

# %% [markdown]
# ### 4.11 What is average loss range of matches by teams?

# %%
loss_by_wickets_trend = sorted_wins_by_wickets[(sorted_wins_by_wickets['loser'] != 'N/A')&\
                                               (sorted_wins_by_wickets['win_by_wickets']!=0)][['loser','win_by_wickets']]
loss_by_wickets_trend.rename(columns={'win_by_wickets':'loss by wickets'}, inplace=True)

# %matplotlib inline
g = sns.catplot(x='loser', y='loss by wickets', data=loss_by_wickets_trend, kind='swarm', aspect=2.5)
g.set_xticklabels(rotation =90)
g.fig.suptitle("Overall Match loss trend")
# Out:
# Text(0.5, 0.98, 'Overall Match loss trend')

# %% [markdown]
# - Maximum Teams lost with in range of __6 to 8__ wickets.
# - Maximum team lost with __6__ wickets.
# - __Kings XI Punjab__ lost maximum 3 times with __10__ wickets.

# %% [markdown]
# ### 4.12 How many times teams managed to win the toss and match both?

# %%
toss_winner_count = matches_processed[['toss_winner','id']].groupby('toss_winner').count()
toss_match_winner = matches_processed[matches_processed['toss_winner']==matches_processed['winner']]
toss_match_winner_count = toss_match_winner[['toss_winner','winner']].groupby('toss_winner').count()

toss_match_winner_count.reset_index(inplace=True)
toss_winner_count.reset_index(inplace=True)

toss_winner_count.rename(columns={'toss_winner':'Teams','id':'count'},inplace=True)
toss_match_winner_count.rename(columns={'toss_winner':'Teams','winner':'count'},inplace=True)

toss_match_winner_count['param'] = 'Toss and Match wins'
toss_winner_count['param'] = 'Toss wins'

frames = [toss_match_winner_count, toss_winner_count]
result = pd.concat(frames)

# %matplotlib inline
g = sns.catplot(x='Teams', y='count', hue='param', data=result, kind='bar', aspect=2.5)
g.set_xticklabels(rotation=90)
g.fig.suptitle("Toss win and Match win trend")
# Out:
# Text(0.5, 0.98, 'Toss win and Match win trend')

# %% [markdown]
# - __Mumbai Indians__ won _toss_ maximum times.
# - __Chennai Super Kings__ won _matches_ maximum times when they won the toss.

# %% [markdown]
# ### 4.13 Which team lost the toss but won the match most?

# %%
toss_loss_count = {}
Teams = np.unique(matches_processed['team1'])
for i in range(0, len(Teams)):
    toss_loss_count[Teams[i]] = 0
for index, row in matches_processed.iterrows():
    if(row['toss_winner'] == row['team1']):
        toss_loss_count[row['team2']] = toss_loss_count[row['team2']]+1
    elif(row['toss_winner'] == row['team2']):
        toss_loss_count[row['team1']] = toss_loss_count[row['team1']]+1
toss_loss_count
toss_loss_countdf = pd.DataFrame.from_dict(toss_loss_count, orient = 'index', columns = ['Matches'])

toss_loser_match_winner = matches_processed[(matches_processed['toss_winner']!=matches_processed['winner'])\
                                           &(matches_processed['winner']!='N/A')]
match_winner_count = toss_loser_match_winner[['id','winner']].groupby('winner').count()

toss_loss_countdf.reset_index(inplace=True)
match_winner_count.reset_index(inplace=True)

match_winner_count.rename(columns={'winner':'Teams', 'id':'Matches'},inplace=True)
toss_loss_countdf.rename(columns={'index':'Teams'},inplace=True)

match_winner_count['param'] = 'Toss Loss Match Wins'
toss_loss_countdf['param'] = 'Total Toss Loss'

frames = [match_winner_count, toss_loss_countdf]
result = pd.concat(frames)

# %matplotlib inline
g = sns.catplot(x='Teams', y='Matches', hue='param', data=result, kind='bar', aspect=2.5)
g.set_xticklabels(rotation=90)
g.fig.suptitle("toss loss but match win trend")
# Out:
# Text(0.5, 0.98, 'toss loss but match win trend')

# %% [markdown]
# - Overall __Royal Challenger Bangalore__ lost maximum _toss_.
# - __Mumbai Indians__ managed to emarged as victorious maximum times even after losing the toss.

# %% [markdown]
# ### 4.14 Which team won the toss and chose to bat first and won the match?

# %%
team_won_toss_bat_match = matches_processed[(((matches_processed['toss_winner'] == matches_processed['winner'])&\
                                            (matches_processed['toss_decision']== 'bat')) &\
                                            (matches_processed['win_by_runs']>0))]
team_won_toss_bat_match_plot = team_won_toss_bat_match[['team1','id']].groupby('team1').count()

team_won_toss_bat_match_plot.reset_index(inplace=True)

team_won_toss_bat_match_plot.rename(columns={'team1':'Teams','id':'Matches'}, inplace=True)

# %matplotlib inline
g = sns.catplot(x='Teams', y='Matches', data=team_won_toss_bat_match_plot,kind='bar', aspect=2.5)
g.set_xticklabels(rotation =90)
g.fig.suptitle("Toss Won - Chose Bat - Victory Count")
# Out:
# Text(0.5, 0.98, 'Toss Won - Chose Bat - Victory Count')

# %% [markdown]
# - __Chennai Super Kings__ won maximum matches when the won the toss and chose to bat.
# - We can say that __Chennai Super Kings__ is best __Defender__.

# %% [markdown]
# ### 4.15 Which team won the toss and chose to field first and won the match?

# %%
team_won_toss_field_match = matches_processed[(((matches_processed['toss_winner'] == matches_processed['winner'])&\
                                            (matches_processed['toss_decision']== 'field')) &\
                                            (matches_processed['win_by_wickets']>0))]
team_won_toss_field_match_plot = team_won_toss_field_match[['team1','id']].groupby('team1').count()

team_won_toss_field_match_plot.reset_index(inplace=True)

team_won_toss_field_match_plot.rename(columns={'team1':'Teams','id':'Matches'}, inplace=True)

# %matplotlib inline
g = sns.catplot(x='Teams', y='Matches', data=team_won_toss_field_match_plot,kind='bar', aspect=2.5)
g.set_xticklabels(rotation =90)
g.fig.suptitle("Toss Won - Chose Field - Victory Count")
# Out:
# Text(0.5, 0.98, 'Toss Won - Chose Field - Victory Count')

# %% [markdown]
# - __Royal Challengers Bangalore__ won maximum times when they won the toss and chose to field.
# - We can say that __Royal Challenger Bangalore__ is best __Chaser__.

# %% [markdown]
# ### 4.15 Who are the best 10 players in IPL?

# %%
player_of_match = matches_processed[['player_of_match', 'id']].groupby('player_of_match').count()
player_of_match.sort_values('id', ascending=False, inplace=True)

player_of_match.reset_index(inplace=True)

player_of_match.rename(columns={'player_of_match':'Man of The Match','id':'No of Matches'}, inplace=True)

# %matplotlib inline
g = sns.catplot(x='Man of The Match', y='No of Matches', data=player_of_match.head(10),kind='bar', aspect=2.5)
g.fig.suptitle("Top 10 Players who won Man of the Matches")
# Out:
# Text(0.5, 0.98, 'Top 10 Players who won Man of the Matches')

# %% [markdown]
# - __CH Gayle__ performed best during __IPL__. He won __20__ times __Man of the Match__ award.

# %% [markdown]
# ### 4.16 What is %age of victory and loss team wise?

# %%
TotalParam = []
TotalMatchdf_new = TotalMatchdf
for i in range(0, len(TotalMatchdf_new['Matches'])):
    TotalParam.append('Total')
TotalMatchdf_new['param'] = pd.Series(TotalParam, index=TotalMatchdf_new.index)
TotalMatchdf_new.index.name='Teams'

TotalMatchdf_new

WinsParam = []
wins_new = wins
wins_new = pd.DataFrame({'Teams':wins_new.index, 'Matches':wins_new.values})
wins_new.set_index('Teams', inplace=True)
for i in range(0, len(wins_new['Matches'])):
    WinsParam.append('wins')
wins_new['param'] = pd.Series(WinsParam, index=wins_new.index)

LossParam = []
loss_new = loss
loss_new = pd.DataFrame({'Teams':loss_new.index, 'Matches':loss_new.values})
loss_new.set_index('Teams',inplace=True)
for i in range(0, len(loss_new['Matches'])):
    LossParam.append('loss')
loss_new['param'] = pd.Series(LossParam, index=loss_new.index)

frames = [TotalMatchdf_new, wins_new, loss_new]
result = pd.concat(frames)
result.rename(columns={'':'Teams'}, inplace=True)
result.reset_index(inplace=True)
result
result = result.drop(result[result['Teams']=='N/A'].index)
result.reset_index(drop=True,inplace=True)
win_loss_tie_df = result
# %matplotlib inline
g = sns.catplot(x='Teams', y='Matches', hue='param', data=win_loss_tie_df, kind='bar', aspect=2.5)
g.set_xticklabels(rotation=90)
g.fig.suptitle("Overall Team Performances")
# Out:
# Text(0.5, 0.98, 'Overall Team Performances')

# %%
Teams = np.unique(matches_processed['team1'])
win_percentage_teamwise = {}
loss_percentage_teamwise = {}
for i in range(0,len(Teams)):
    winscon = (win_loss_tie_df['Teams']==Teams[i])&(win_loss_tie_df['param']=='wins')
    losscon = (win_loss_tie_df['Teams']==Teams[i])&(win_loss_tie_df['param']=='loss')
    totalcon = (win_loss_tie_df['Teams']==Teams[i])&(win_loss_tie_df['param']=='Total')
    winscount = win_loss_tie_df.loc[winscon, 'Matches'].iat[0]
    losscount = win_loss_tie_df.loc[losscon, 'Matches'].iat[0]
    totalcount = win_loss_tie_df.loc[totalcon, 'Matches'].iat[0]
    win_percentage_teamwise[Teams[i]] = int(((winscount * 100)/totalcount))
    loss_percentage_teamwise[Teams[i]] = int(((losscount * 100)/totalcount))

win_percentage_teamwise_df = pd.DataFrame.from_dict(win_percentage_teamwise, orient='index')
win_percentage_teamwise_df.reset_index(inplace=True)
win_percentage_teamwise_df.rename(columns={'index':'Teams',0:'percentage'},inplace=True)
win_percentage_teamwise_df['param'] = 'win%'

loss_percentage_teamwise_df = pd.DataFrame.from_dict(loss_percentage_teamwise, orient='index')
loss_percentage_teamwise_df.reset_index(inplace=True)
loss_percentage_teamwise_df.rename(columns={'index':'Teams',0:'percentage'},inplace=True)
loss_percentage_teamwise_df['param'] = 'loss%'

frames = [win_percentage_teamwise_df, loss_percentage_teamwise_df]
result = pd.concat(frames)

result.reset_index(inplace=True)

result.drop('index',inplace=True, axis=1)
result

# %matplotlib inline
g = sns.catplot(x='Teams', y='percentage', hue='param', data=result, kind='bar', aspect=2.5)
g.set_xticklabels(rotation=90)
g.fig.suptitle("Overall Team Performances in %age")
# Out:
# Text(0.5, 0.98, 'Overall Team Performances in %age')

# %% [markdown]
# - In win percentage __Chennai Super Kings__ secured Maximum victories.
# - In loss percentage __Pune Warriors__ have maximum loss.

# %% [markdown]
# ## 5 Conclusions

# %% [markdown]
# - __Mumbai Indians__ has _won_ maximum number of matches.
# - __Delhi Daredevlis__ has _lost_ maximum number of matches.
# - _Mumbai Indians_ played maximum number of matches.
# - __Mumbai Indians__ is the _best defender_ as they have won maximum matches by run.
# - __Kolkata Knight Riders__ is the _best Chaser_ as they have won maximum matches by wickets.
# - __Mumbai Indians__ _won maximum_ number of matches when they _won the toss_ where as __Chennai Super Kings__ _won maximum_ percentage of matches when _won the toss_.
# - __Chennai Super Kings__ _won maximum_ number of mathes while they _won the toss then chose to bat_. whereas __Royal Challenger Bangalore__ was able to _won maximum_ matches when they _won the toss and chose to field_.
# - Overall __Chennai Super Kings__ has _maximum winning percentage_ and __Pune warriors__ has _maximum loss percentage_.
# - __CH Gayle__ _won maximum number of Man of The Match Titles_.

# %% [markdown]
# ## Action Items

# %% [markdown]
# - In ILP __Chennai Super Kings__ is best to get tendor. Next close teams are __Mumbai Indians, Sunrises Hyderabad and Kolkata Knight Riders__.
# - In ILP __Rising Pune Supergiant__ has 50-50 winning and loss chances.
# - __Delhi Daredevils, Royal Challenger Bangalore, Pune Wariors and Kochi Tuskers Kerela__ needs to train more as they have more lossing percentage then winning percentage.
# - We have almost 30 players with more than 5 times __Man of the Match__ award and __CH Gayle__ won maximum times ie __20__. so getting him in team will benifit the team.
